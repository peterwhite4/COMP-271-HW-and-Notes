# %% [markdown]
# UNIT TESTING

# %%
#    a -> --------
#         | mult |  
#    b -> |      |
#         --------
#                   ->>> C


#    Test input  |   Predicted output    |   Real output
#    ----------------------------------------------------
#    2,2         |   4                   |   4
#    3,3         |   9                   |   0
#    5,0         |   0                   |   0
#    314,2       |   628                 |   628
#    -1,-2       |   +2                  |   2


#    Use "assert" for python

# %%
# For example
def test_upper(self):
    self.assertEqual('foo'.upper(), 'FOO')

# %% [markdown]
# ASSERT
#
# - A unit test checks if code behaves as expected.
# - .upper() converts a string to all uppercase letters.
# - 'foo'.upper() returns 'FOO'.
# - assertEqual(a, b) checks if a == b.
# - If the values are equal, the test passes.
# - If the values are not equal, the test fails.
# - 'OOF' is 'FOO' reversed.
# - [::-1] reverses a string in Python.
# - self refers to the current class instance.
# - self.assertEqual() is used inside a unittest class.

# %% [markdown]
# COMPLEX NUMBER NOTES

# %% [markdown]
# z = a + ib
# a = re
# ib = im
#
# -----------
# |Complex  |
# -----------
# |re: float|
# |im: float|
# -----------
# |methods  |
# -----------

# %%
from __future__ import annotations

class Complex:
        
        def __init__(self, re:float, im:float) -> None:
                self.re = re
                self.im = im

        def __str__(self) -> str:
                return f"{self.re} + {self.im}i"

        def add(self, other:Complex) -> Complex:
                """Adds two numbers in the form
                z1 = a+ib
                z2 = c+id
                and returns
                (a+c) + i(b+d)
                """
                return Complex(self.re + other.re, self.im + other.im)

        def __add__(self, other:Complex) -> Complex:
                return self.add(other)
        
        def subtract(self, other:Complex) -> Complex:
                return Complex(self.re - other.re, self.im - other.im)
        

# Test
z1 = Complex(1, 2)
z2 = Complex(3, 4)
print(z1.add(z2))
# Out:
# 4 + 6i
