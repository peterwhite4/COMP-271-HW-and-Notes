# %% [markdown]
# Associative arrays, content addressable memory, and hashing.

# %%
# If we have our class of people. If someone asks the teacher if "Peter" was at class, how can the teacher (as a program)
# I was at the class.

# In order to do this, we have a list [1-25] for the alphabet and reference 16 for "P" and put Peter in there."""


# CAM -> Domian
# Student ID <- Students
# Vin <- Vehicles
# SSN or TIN <- IRS
# Parcel # <- Cook County accessor
# ssbn <- books


# N13 O14 M15

# %% [markdown]
# HASHING

# %%
# ASCII value for A = 65 / a = 92 / 0 = 48 / (space) = 32
#
# 
#
""""Example hash function method"""
def hash(string:str) -> int:
    # Assume not empty
    hash_value = 0
    p = 31
    for i in range(len(string)):
        print(f"{string[i]=} has ASCII value for {ord(string[i]):3}")
        hash_value = (p*i)*ord(string[i])
